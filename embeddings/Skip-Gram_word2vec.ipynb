# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter 
import random
## Your code here
threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs={word:count/total_count for word,count in word_counts.items()}
p_drop = {word:1-np.sqrt(threshold/freqs[word]) for word in word_counts}
# The final subsampled word list
train_words = [word for word in int_words if random.random() < (1-p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1,1+window_size)
    start = idx-R if(idx-R>0) else 0
    end = idx + R
    target_word = set(words[start:idx]+words[idx+1:end+1])
    return list(target_word)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,None,name='inputs')
    labels = tf.placeholder(tf.int32,[None,None],name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding),-1,1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding,inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab,n_embedding),stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,labels,embed,n_sampled,n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# 子目录或文件 checkpoints 已经存在。

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6696 0.4092 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6221 0.4050 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5016 0.4108 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6137 0.4130 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5163 0.4125 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5226 0.4174 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5379 0.4313 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5708 0.4122 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4519 0.4188 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4056 0.4102 sec/batch
# Nearest to d: lakewood, jacobson, officer, yokoi, technik, afrikaans, halakhah, morrie,
# Nearest to will: espouse, task, vied, allen, robustus, made, hakim, hissar,
# Nearest to is: dropout, excommunicating, female, patrolled, poetica, kellogg, refurbished, created,
# Nearest to he: richardson, exposition, simo, odysseus, cymbals, koalas, rails, emotionally,
# Nearest to of: celtic, interglacials, saloon, upholstery, inherited, saeima, trying, bakersfield,
# Nearest to use: mallow, graham, part, affidavit, yakima, cognition, saar, imdb,
# Nearest to as: ides, enclosures, emptying, walkers, osborn, nobel, termed, mahathir,
# Nearest to eight: highs, impurity, foiled, manifolds, mocha, cbs, smash, nicodemus,
# Nearest to running: tutoring, evangelicals, fianna, voices, talib, nok, mohandas, screwtape,
# Nearest to arts: callaghan, doran, armies, incarnated, florian, malta, timed, studied,
# Nearest to institute: dowd, gingerbread, dna, thermionic, anglesey, brock, privacy, redundant,
# Nearest to operations: thelma, cataphract, gait, senex, mortars, rijndael, yom, theology,
# Nearest to placed: profitable, custer, freedom, movers, homeostatic, bondage, craftsman, autocracy,
# Nearest to know: klondike, player, choate, sgml, trackways, skating, intimidated, petrov,
# Nearest to http: sie, ricin, subdirectories, subtle, legumes, climatology, foregrip, fanpage,
# Nearest to animals: jodie, partisan, social, risked, speculates, requested, versatile, ej,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4793 0.4299 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3761 0.4043 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3393 0.4036 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2537 0.4024 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1694 0.3974 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1614 0.4041 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0751 0.4053 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0531 0.4078 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0069 0.3960 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9794 0.4116 sec/batch
# Nearest to d: lakewood, officer, jacobson, yokoi, message, particle, wall, lecturer,
# Nearest to will: task, made, espouse, allen, vied, depth, robustus, hakim,
# Nearest to is: dropout, female, created, excommunicating, reach, patrolled, framework, such,
# Nearest to he: exposition, richardson, simo, rails, emotionally, parallel, incorporated, hiberno,
# Nearest to of: trying, celtic, saloon, french, interglacials, inherited, trademark, larry,
# Nearest to use: part, graham, mallow, believe, cognition, preferring, imdb, military,
# Nearest to as: ides, enclosures, termed, wear, emptying, walkers, illustrated, adjacent,
# Nearest to eight: impurity, highs, manifolds, mocha, foiled, widely, cbs, smash,
# Nearest to running: tutoring, voices, evangelicals, talib, fianna, cameroon, could, values,
# Nearest to arts: armies, timed, japan, malta, studied, seeking, terminate, callaghan,
# Nearest to institute: dowd, gingerbread, dna, redundant, privacy, employed, theorists, candidate,
# Nearest to operations: thelma, bramble, gait, keep, licensing, rijndael, array, atomic,
# Nearest to placed: freedom, profitable, rather, kaye, coronal, undamaged, jammed, literacy,
# Nearest to know: player, klondike, arrangements, choate, sgml, office, either, intimidated,
# Nearest to http: subtle, ricin, subdirectories, sie, legumes, foregrip, expected, climatology,
# Nearest to animals: social, partisan, jodie, requested, versatile, risked, prominence, moves,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9230 0.4166 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9171 0.4087 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8507 0.4045 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8549 0.4118 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8189 0.4697 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8138 0.4633 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7890 0.4657 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7870 0.4117 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7753 0.3990 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7752 0.3973 sec/batch
# Nearest to d: lakewood, officer, jacobson, lecturer, particle, message, exporting, wall,
# Nearest to will: task, espouse, vied, made, robustus, allen, depth, hakim,
# Nearest to is: dropout, patrolled, created, macedonian, poetica, truths, acceleration, kellogg,
# Nearest to he: exposition, richardson, emotionally, simo, incorporated, rails, holland, hiberno,
# Nearest to of: trying, saloon, celtic, trademark, dyne, liberalism, french, inherited,
# Nearest to use: graham, part, deprecated, mallow, cognition, gatt, believe, imdb,
# Nearest to as: ides, wear, enclosures, relegated, indexing, albrecht, rumor, emptying,
# Nearest to eight: highs, impurity, foiled, smash, mocha, paved, manifolds, ewan,
# Nearest to running: tutoring, evangelicals, voices, fianna, talib, cameroon, transporting, seasons,
# Nearest to arts: armies, seeking, malta, studied, doran, rights, timed, japan,
# Nearest to institute: dowd, gingerbread, dna, redundant, privacy, proprietary, edwards, brock,
# Nearest to operations: gait, bramble, licensing, thelma, array, atomic, keep, rijndael,
# Nearest to placed: freedom, profitable, rather, literacy, providing, coronal, aren, kaye,
# Nearest to know: player, fill, intimidated, skating, klondike, choate, sgml, arrangements,
# Nearest to http: subtle, subdirectories, pdf, ricin, climatology, sie, legumes, expected,
# Nearest to animals: social, jodie, partisan, requested, versatile, risked, moves, gush,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7828 0.4023 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7434 0.4072 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7236 0.4008 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7007 0.4023 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7408 0.4005 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6829 0.4037 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6951 0.4041 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7322 0.3994 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7070 0.3978 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6690 0.3958 sec/batch
# Nearest to d: lecturer, lakewood, officer, exporting, jacobson, mann, premieres, halakhah,
# Nearest to will: espouse, vied, task, robustus, made, hwang, depth, unskilled,
# Nearest to is: patrolled, dropout, kellogg, each, poetica, macedonian, karst, ff,
# Nearest to he: richardson, emotionally, exposition, incorporated, simo, her, sister, atrocities,
# Nearest to of: trying, liberalism, celtic, upholstery, saloon, dyne, saeima, inherited,
# Nearest to use: graham, deprecated, part, mallow, gatt, cognition, affidavit, believe,
# Nearest to as: ides, wear, enclosures, relegated, indexing, installs, albrecht, rumor,
# Nearest to eight: ewan, paved, highs, bryan, impurity, abstractions, carl, smash,
# Nearest to running: tutoring, evangelicals, voices, fianna, talib, runeword, facilities, cameroon,
# Nearest to arts: seeking, armies, studied, florian, doran, malta, rights, callaghan,
# Nearest to institute: dowd, redundant, gingerbread, edwards, privacy, proprietary, anglesey, dna,
# Nearest to operations: gait, array, thelma, bramble, licensing, atomic, keep, rijndael,
# Nearest to placed: freedom, profitable, coronal, custer, craftsman, rather, borough, movers,
# Nearest to know: fill, player, intimidated, skating, sgml, gauges, choate, dispersion,
# Nearest to http: ricin, subdirectories, climatology, pdf, sie, fanpage, subtle, legumes,
# Nearest to animals: social, jodie, partisan, risked, versatile, embargo, requested, moves,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6972 0.4043 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6696 0.4045 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6269 0.4059 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6020 0.4084 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6265 0.4072 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6424 0.3999 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6054 0.2856 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5467 0.4188 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4997 0.4079 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4864 0.4153 sec/batch
# Nearest to d: officer, lecturer, politician, architect, sculptor, lakewood, actress, mann,
# Nearest to will: espouse, vied, task, robustus, hwang, depth, unskilled, made,
# Nearest to is: each, patrolled, required, kellogg, poetica, dropout, karst, macedonian,
# Nearest to he: richardson, emotionally, exposition, her, sister, odysseus, son, occasions,
# Nearest to of: trying, liberalism, patriarchal, determinism, upholstery, saeima, dodecahedra, outwardly,
# Nearest to use: deprecated, gatt, part, cognition, mallow, realtime, warms, graham,
# Nearest to as: ides, wear, enclosures, mahathir, installs, relegated, assault, emptying,
# Nearest to eight: carl, nine, seven, ewan, bryan, charles, franz, three,
# Nearest to running: tutoring, evangelicals, voices, fianna, talib, runeword, floor, seasons,
# Nearest to arts: seeking, doran, florian, studied, armies, malta, televison, rights,
# Nearest to institute: dowd, gingerbread, edwards, candidate, jin, anglesey, redundant, physique,
# Nearest to operations: gait, atomic, array, licensing, rijndael, bramble, thelma, keep,
# Nearest to placed: freedom, profitable, coronal, craftsman, autocracy, custer, rather, movers,
# Nearest to know: fill, dispersion, intimidated, campania, sgml, proofs, skating, gauges,
# Nearest to http: pdf, subdirectories, climatology, ricin, fanpage, sie, foregrip, jiro,
# Nearest to animals: social, jodie, partisan, versatile, moves, risked, embargo, surveys,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4970 0.4050 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4876 0.3991 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4353 0.3926 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5557 0.3820 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5107 0.3823 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4857 0.3844 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4722 0.3845 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4047 0.3886 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4270 0.3881 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4412 0.3852 sec/batch
# Nearest to d: officer, lakewood, lecturer, mann, politician, jacobson, sculptor, architect,
# Nearest to will: espouse, vied, task, robustus, made, hwang, unskilled, metaphorical,
# Nearest to is: each, required, kellogg, alternatively, patrolled, reach, anaerobic, dropout,
# Nearest to he: richardson, emotionally, exposition, son, her, sister, odysseus, koalas,
# Nearest to of: dodecahedra, trying, upholstery, oaths, liberalism, treadmill, patriarchal, determinism,
# Nearest to use: deprecated, gatt, cognition, computations, devices, warms, part, mallow,
# Nearest to as: ides, enclosures, relegated, mahathir, wear, installs, kuroda, glee,
# Nearest to eight: highs, mocha, paved, carl, rukh, three, foiled, ewan,
# Nearest to running: tutoring, voices, seasons, fianna, cameroon, talib, floor, evangelicals,
# Nearest to arts: doran, seeking, florian, studied, televison, incarnated, armies, lombards,
# Nearest to institute: dowd, gingerbread, edwards, jin, anglesey, candidate, proprietary, inuktitut,
# Nearest to operations: array, atomic, licensing, gait, keep, rijndael, bramble, xnor,
# Nearest to placed: freedom, profitable, coronal, custer, craftsman, movers, rearranging, jammed,
# Nearest to know: fill, dispersion, proofs, campania, intimidated, sgml, choate, either,
# Nearest to http: pdf, subdirectories, climatology, www, ricin, fanpage, com, sie,
# Nearest to animals: jodie, social, versatile, moves, partisan, risked, mauricio, surveys,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4298 0.3863 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4042 0.3909 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4111 0.3978 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4076 0.4153 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3994 0.4213 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4621 0.4003 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3919 0.3959 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4082 0.4006 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4240 0.4018 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3520 0.4032 sec/batch
# Nearest to d: lakewood, officer, lecturer, mann, jacobson, halakhah, sculptor, zquez,
# Nearest to will: espouse, vied, task, robustus, made, hwang, metaphorical, mentats,
# Nearest to is: required, each, e, poetica, dropout, anaerobic, denotes, alternatively,
# Nearest to he: richardson, sister, emotionally, son, her, exposition, occasions, cymbals,
# Nearest to of: dodecahedra, upholstery, liberalism, trying, patriarchal, dyne, stoppages, saeima,
# Nearest to use: deprecated, gatt, devices, cognition, computations, part, warms, realtime,
# Nearest to as: ides, enclosures, relegated, mahathir, kuroda, albrecht, wear, installs,
# Nearest to eight: highs, carl, foiled, rukh, three, bryan, ewan, mocha,
# Nearest to running: tutoring, floor, voices, fianna, seasons, soiled, belarussian, talib,
# Nearest to arts: doran, florian, seeking, televison, studied, incarnated, poetic, lombards,
# Nearest to institute: dowd, edwards, anglesey, gingerbread, jin, candidate, thermionic, proprietary,
# Nearest to operations: array, atomic, licensing, gait, rijndael, keep, xnor, bramble,
# Nearest to placed: freedom, profitable, coronal, craftsman, disgrace, autocracy, custer, rearranging,
# Nearest to know: fill, campania, intimidated, proofs, player, dispersion, telekinesis, plotinus,
# Nearest to http: pdf, www, com, subdirectories, climatology, edu, ricin, fanpage,
# Nearest to animals: social, jodie, versatile, moves, partisan, risked, pyrrhus, subtropical,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3682 0.4176 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3996 0.4249 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3457 0.4006 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3585 0.4022 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3990 0.3996 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3621 0.4043 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3760 0.4033 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3669 0.4030 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3346 0.4008 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3376 0.3980 sec/batch
# Nearest to d: lakewood, lecturer, mann, jacobson, officer, particle, sculptor, halakhah,
# Nearest to will: espouse, task, vied, robustus, mentats, unskilled, hwang, any,
# Nearest to is: each, required, anaerobic, poetica, e, alternatively, patrolled, cholas,
# Nearest to he: sister, richardson, son, her, emotionally, odysseus, exposition, cymbals,
# Nearest to of: dodecahedra, patriarchal, chairmanship, liberalism, dyne, french, secular, hellenistic,
# Nearest to use: deprecated, gatt, cognition, warms, pedals, ephemerides, computations, mallow,
# Nearest to as: ides, enclosures, mahathir, relegated, synthesisers, reconcile, safeguard, assault,
# Nearest to eight: three, highs, foiled, rukh, greer, mocha, carl, six,
# Nearest to running: tutoring, nok, floor, voices, belarussian, fianna, seasons, soiled,
# Nearest to arts: florian, doran, studied, televison, seeking, incarnated, poetic, hsk,
# Nearest to institute: dowd, anglesey, edwards, jin, gingerbread, uiuc, brock, penthouse,
# Nearest to operations: array, atomic, licensing, rijndael, keep, xnor, stalingrad, applies,
# Nearest to placed: freedom, profitable, disgrace, coronal, rather, autocracy, craftsman, custer,
# Nearest to know: player, fill, proofs, anybody, telekinesis, plotinus, sgml, dispersion,
# Nearest to http: pdf, www, com, subdirectories, html, edu, index, external,
# Nearest to animals: social, jodie, versatile, subtropical, partisan, moves, pyrrhus, undulating,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3599 0.4063 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2915 0.4042 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3728 0.4021 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3786 0.4003 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4165 0.4039 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3005 0.4019 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3108 0.4011 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3445 0.4011 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2201 0.4052 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3043 0.3983 sec/batch
# Nearest to d: mann, sculptor, lakewood, lecturer, officer, zquez, architect, politician,
# Nearest to will: espouse, vied, task, mentats, unskilled, robustus, made, metaphorical,
# Nearest to is: each, required, anaerobic, e, alternatively, poetica, cholas, enclosing,
# Nearest to he: sister, emotionally, richardson, her, had, odysseus, son, mother,
# Nearest to of: dodecahedra, nyasaland, patriarchal, mali, coerced, french, dyne, saeima,
# Nearest to use: gatt, deprecated, warms, part, pedals, affidavit, cognition, ephemerides,
# Nearest to as: ides, enclosures, relegated, mahathir, synthesisers, osborn, safeguard, reconcile,
# Nearest to eight: three, nine, greer, six, two, rukh, seven, carl,
# Nearest to running: tutoring, floor, nok, belarussian, seasons, fianna, route, soiled,
# Nearest to arts: studied, florian, doran, televison, seeking, smyrnaeans, poetic, sciences,
# Nearest to institute: dowd, anglesey, edwards, science, universities, jin, gingerbread, doctorate,
# Nearest to operations: array, atomic, licensing, xnor, stalingrad, mortars, rijndael, keep,
# Nearest to placed: freedom, profitable, disgrace, autocracy, coronal, craftsman, utilized, rather,
# Nearest to know: player, anybody, fill, proofs, cast, sgml, telekinesis, dispersion,
# Nearest to http: pdf, www, com, html, edu, subdirectories, external, htm,
# Nearest to animals: jodie, social, subtropical, versatile, moves, pyrrhus, well, undulating,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3055 0.4081 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3216 0.3996 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3178 0.1784 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2665 0.4051 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2472 0.4034 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2463 0.4062 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2005 0.3917 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2123 0.3839 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2323 0.3844 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1754 0.3819 sec/batch
# Nearest to d: lakewood, zquez, mann, sculptor, lecturer, officer, jacobson, politician,
# Nearest to will: espouse, vied, task, mentats, robustus, made, unskilled, any,
# Nearest to is: each, cholas, reach, enclosing, alternatively, denotes, peltier, anaerobic,
# Nearest to he: sister, son, her, had, odysseus, emotionally, mother, richardson,
# Nearest to of: dodecahedra, nyasaland, mali, patriarchal, inherited, saeima, upholstery, ruled,
# Nearest to use: deprecated, gatt, pedals, part, affidavit, warms, cognition, papillon,
# Nearest to as: ides, relegated, mahathir, enclosures, synthesisers, shalem, view, osborn,
# Nearest to eight: three, rukh, nine, greer, two, six, carl, foiled,
# Nearest to running: tutoring, route, floor, seasons, bat, belarussian, soiled, nok,
# Nearest to arts: florian, studied, televison, doran, sciences, smyrnaeans, poetic, seeking,
# Nearest to institute: dowd, science, anglesey, doctorate, universities, uiuc, gingerbread, edwards,
# Nearest to operations: array, atomic, xnor, mortars, licensing, rijndael, stalingrad, begin,
# Nearest to placed: freedom, profitable, disgrace, coronal, autocracy, craftsman, utilized, movers,
# Nearest to know: anybody, player, fill, telekinesis, thing, proofs, cast, sgml,
# Nearest to http: pdf, www, com, html, edu, index, external, htm,
# Nearest to animals: social, jodie, versatile, subtropical, well, hunting, pyrrhus, surveys,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2440 0.3910 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2218 0.3871 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2260 0.3826 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1345 0.3841 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1613 0.3857 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1915 0.3821 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1521 0.3810 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1840 0.3837 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1703 0.3844 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1660 0.3826 sec/batch
# Nearest to d: lakewood, jacobson, particle, mann, zquez, lecturer, officer, halakhah,
# Nearest to will: espouse, vied, mentats, task, any, made, metaphorical, unskilled,
# Nearest to is: each, required, denotes, anaerobic, enclosing, kana, alternatively, authority,
# Nearest to he: had, sister, odysseus, her, son, emotionally, richardson, simo,
# Nearest to of: dodecahedra, inherited, interglacials, saeima, patriarchal, nyasaland, fluent, dyne,
# Nearest to use: gatt, pedals, deprecated, part, imposes, warms, computations, affidavit,
# Nearest to as: ides, mahathir, relegated, enclosures, synthesisers, view, reconcile, often,
# Nearest to eight: three, rukh, two, six, greer, foiled, nine, asg,
# Nearest to running: tutoring, belarussian, seasons, soiled, floor, route, nok, bat,
# Nearest to arts: sciences, televison, florian, studied, doran, smyrnaeans, college, hall,
# Nearest to institute: doctorate, universities, dowd, science, anglesey, undergraduate, edwards, jin,
# Nearest to operations: array, atomic, xnor, stalingrad, evacuation, rijndael, mortars, keep,
# Nearest to placed: profitable, freedom, coronal, disgrace, utilized, craftsman, wind, movers,
# Nearest to know: player, anybody, dispersion, fill, telekinesis, thing, we, sgml,
# Nearest to http: pdf, www, com, edu, html, index, external, htm,
# Nearest to animals: social, jodie, hunting, subtropical, versatile, greasy, specimens, adapts,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1661 0.3847 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2303 0.3809 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1796 0.3814 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1403 0.3785 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1810 0.3788 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1889 0.3802 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2054 0.3824 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1441 0.3802 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1355 0.3831 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1790 0.3808 sec/batch
# Nearest to d: lakewood, mann, jacobson, zquez, particle, officer, lecturer, sculptor,
# Nearest to will: espouse, mentats, any, vied, task, hackerdom, unskilled, doesn,
# Nearest to is: required, each, denotes, authority, enclosing, infty, rangle, between,
# Nearest to he: had, odysseus, emotionally, sister, her, cymbals, simo, unhelpful,
# Nearest to of: dodecahedra, inherited, interglacials, ldots, fluent, botanic, nyasaland, saeima,
# Nearest to use: gatt, pedals, part, deprecated, imposes, affidavit, cognition, realtime,
# Nearest to as: ides, mahathir, relegated, enclosures, view, often, reconcile, recognizing,
# Nearest to eight: three, nine, six, two, four, rukh, greer, foiled,
# Nearest to running: belarussian, tutoring, route, floor, soiled, nok, seasons, precautionary,
# Nearest to arts: sciences, studied, televison, college, florian, smyrnaeans, hall, doran,
# Nearest to institute: doctorate, universities, dowd, science, anglesey, ph, uiuc, edwards,
# Nearest to operations: array, atomic, xnor, evacuation, stalingrad, rijndael, mortars, begin,
# Nearest to placed: profitable, disgrace, freedom, coronal, craftsman, built, wind, utilized,
# Nearest to know: player, anybody, fill, we, thing, plotinus, telekinesis, proofs,
# Nearest to http: www, pdf, com, edu, html, htm, index, gov,
# Nearest to animals: jodie, social, specimens, hunting, subtropical, plants, undulating, greasy,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1897 0.3870 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1711 0.3839 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1982 0.3815 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1814 0.3830 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1367 0.3850 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1420 0.3850 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1783 0.3852 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1315 0.3846 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1824 0.3862 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2273 0.3857 sec/batch
# Nearest to d: sculptor, zquez, architect, ois, mann, lakewood, henri, eug,
# Nearest to will: espouse, unskilled, mentats, any, vied, hackerdom, doesn, metaphorical,
# Nearest to is: authority, each, required, denotes, shaanxi, rangle, infty, collaboratively,
# Nearest to he: had, odysseus, sister, emotionally, mother, son, her, simo,
# Nearest to of: nyasaland, dodecahedra, inherited, patriarchal, britain, barth, nyt, coerced,
# Nearest to use: deprecated, pedals, gatt, imposes, imdb, part, affidavit, realtime,
# Nearest to as: ides, mahathir, relegated, reconcile, safeguard, officialdom, osborn, enclosures,
# Nearest to eight: three, two, six, nine, four, seven, one, greer,
# Nearest to running: belarussian, nok, tutoring, route, floor, soiled, fianna, freenet,
# Nearest to arts: sciences, studied, college, televison, florian, hall, smyrnaeans, tulip,
# Nearest to institute: doctorate, universities, science, undergraduate, faculty, ph, dowd, uiuc,
# Nearest to operations: evacuation, array, atomic, xnor, mortars, stalingrad, rijndael, able,
# Nearest to placed: freedom, disgrace, coronal, profitable, autocracy, craftsman, movers, built,
# Nearest to know: player, anybody, we, thing, fill, telekinesis, laments, plotinus,
# Nearest to http: www, pdf, com, edu, html, htm, gov, https,
# Nearest to animals: social, jodie, specimens, hunting, mauricio, plants, orangutan, greasy,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2447 0.3885 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1503 0.3837 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1347 0.3814 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1545 0.3832 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.9981 0.3836 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1361 0.3835 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1287 0.3848 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1380 0.3849 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1582 0.0615 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1494 0.3956 sec/batch
# Nearest to d: sculptor, zquez, lakewood, mann, jacobson, particle, architect, ois,
# Nearest to will: espouse, unskilled, mentats, any, hackerdom, vied, requires, metaphorical,
# Nearest to is: denotes, rangle, each, required, enclosing, infty, reach, there,
# Nearest to he: had, odysseus, emotionally, sister, preseason, professor, unhelpful, simo,
# Nearest to of: dodecahedra, nyasaland, inherited, the, interglacials, nyt, in, postdoctoral,
# Nearest to use: pedals, deprecated, gatt, part, support, imposes, realtime, papillon,
# Nearest to as: ides, mahathir, often, synthesisers, shalem, relegated, osborn, enclosures,
# Nearest to eight: three, nine, two, six, four, greer, rukh, seven,
# Nearest to running: belarussian, backwards, route, tutoring, soiled, nok, freenet, voices,
# Nearest to arts: sciences, studied, college, smyrnaeans, televison, florian, hall, tulip,
# Nearest to institute: doctorate, universities, science, undergraduate, faculty, ph, uiuc, dowd,
# Nearest to operations: xnor, array, evacuation, mortars, atomic, stalingrad, able, rijndael,
# Nearest to placed: coronal, disgrace, freedom, profitable, built, autocracy, wind, craftsman,
# Nearest to know: player, anybody, we, fill, laments, thing, telekinesis, dispersion,
# Nearest to http: www, pdf, com, edu, html, gov, index, https,
# Nearest to animals: social, specimens, jodie, orangutan, artificial, adapts, greasy, hunting,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0898 0.3909 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0678 0.3891 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0991 0.3843 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0244 0.3903 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0879 0.3851 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0287 0.3860 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0915 0.3819 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0943 0.3821 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1370 0.3807 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0261 0.3800 sec/batch
# Nearest to d: sculptor, zquez, jacobson, lakewood, particle, milburn, mann, henri,
# Nearest to will: espouse, any, mentats, unskilled, hackerdom, doesn, everlasting, requires,
# Nearest to is: each, required, denotes, shaanxi, reach, rangle, authority, there,
# Nearest to he: had, odysseus, emotionally, preseason, unhelpful, sister, him, son,
# Nearest to of: dodecahedra, inherited, the, nyasaland, in, nyt, abbasid, hellenistic,
# Nearest to use: pedals, deprecated, gatt, imposes, part, support, electromotive, papillon,
# Nearest to as: ides, often, mahathir, synthesisers, relegated, descended, ours, hearty,
# Nearest to eight: three, nine, two, four, six, foiled, rukh, greer,
# Nearest to running: route, belarussian, nok, tutoring, soiled, backwards, freenet, voices,
# Nearest to arts: sciences, studied, college, televison, smyrnaeans, hall, florian, tulip,
# Nearest to institute: doctorate, universities, science, uiuc, faculty, ph, undergraduate, dowd,
# Nearest to operations: xnor, array, evacuation, stalingrad, rijndael, mortars, able, atomic,
# Nearest to placed: built, coronal, disgrace, freedom, wind, profitable, spores, autocracy,
# Nearest to know: player, anybody, fill, we, laments, thing, telekinesis, dispersion,
# Nearest to http: www, com, pdf, edu, html, htm, https, gov,
# Nearest to animals: social, jodie, specimens, orangutan, greasy, eaters, mauricio, artificial,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0384 0.3881 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0156 0.3834 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0138 0.3774 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0638 0.3821 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0787 0.3824 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0558 0.3822 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0650 0.3848 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0972 0.3799 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0773 0.3819 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0268 0.3804 sec/batch
# Nearest to d: particle, jacobson, sculptor, zquez, lakewood, physica, milburn, morrie,
# Nearest to will: espouse, any, mentats, unskilled, so, hackerdom, enveloped, metaphorical,
# Nearest to is: infty, required, denotes, each, e, rangle, authority, solipsism,
# Nearest to he: had, odysseus, emotionally, sister, preseason, him, his, mother,
# Nearest to of: dodecahedra, the, inherited, in, has, spacetime, nyasaland, a,
# Nearest to use: pedals, deprecated, gatt, electromotive, imposes, part, graham, computations,
# Nearest to as: ides, often, mahathir, ours, relegated, synthesisers, hearty, view,
# Nearest to eight: three, two, nine, six, four, seven, five, one,
# Nearest to running: route, belarussian, nok, soiled, backwards, voices, freenet, floor,
# Nearest to arts: sciences, college, studied, hall, televison, smyrnaeans, attending, humanities,
# Nearest to institute: doctorate, universities, science, undergraduate, ph, uiuc, faculty, dowd,
# Nearest to operations: xnor, array, evacuation, stalingrad, rijndael, mortars, completion, atomic,
# Nearest to placed: coronal, built, disgrace, wind, freedom, spores, socialiste, profitable,
# Nearest to know: player, anybody, we, fill, thing, telekinesis, laments, plotinus,
# Nearest to http: www, com, pdf, edu, html, htm, https, gov,
# Nearest to animals: jodie, social, specimens, orangutan, adapts, eaters, hunting, mauricio,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0657 0.3846 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0760 0.3803 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0574 0.3822 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0803 0.3795 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0775 0.3812 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0474 0.3826 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0730 0.3779 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0598 0.3843 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0992 0.3856 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0779 0.3794 sec/batch
# Nearest to d: jacobson, particle, zquez, sculptor, kernel, morrie, maybach, mann,
# Nearest to will: espouse, unskilled, any, mentats, everlasting, hackerdom, so, metaphorical,
# Nearest to is: denotes, required, infty, rangle, authority, shaanxi, solipsism, each,
# Nearest to he: had, professor, sister, preseason, odysseus, his, emotionally, unhelpful,
# Nearest to of: the, dodecahedra, inherited, nyasaland, in, by, dominion, chairmanship,
# Nearest to use: pedals, deprecated, gatt, imposes, omit, electromotive, graham, kilocalories,
# Nearest to as: ides, often, mahathir, ours, relegated, synthesisers, unbroken, allophone,
# Nearest to eight: nine, three, two, four, six, rukh, one, five,
# Nearest to running: belarussian, nok, route, freenet, queue, fianna, backwards, tutoring,
# Nearest to arts: sciences, college, studied, televison, hall, attending, specialized, smyrnaeans,
# Nearest to institute: doctorate, universities, faculty, undergraduate, ph, science, uiuc, jin,
# Nearest to operations: evacuation, xnor, array, stalingrad, mortars, rijndael, keep, overheat,
# Nearest to placed: built, disgrace, coronal, wind, freedom, spores, socialiste, electrolysis,
# Nearest to know: player, anybody, we, fill, telekinesis, thing, answers, laments,
# Nearest to http: www, edu, com, pdf, html, gov, https, htm,
# Nearest to animals: jodie, social, orangutan, specimens, eaters, adapts, mauricio, sensations,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0466 0.3851 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0009 0.3818 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0270 0.3833 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0505 0.3831 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0864 0.3824 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1433 0.3819 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1053 0.3800 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0338 0.3817 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0513 0.3812 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0483 0.3842 sec/batch
# Nearest to d: sculptor, jacobson, zquez, particle, maybach, alain, morrie, milburn,
# Nearest to will: espouse, unskilled, any, mentats, everlasting, metaphorical, hackerdom, requires,
# Nearest to is: denotes, infty, rangle, e, required, kets, each, there,
# Nearest to he: had, professor, his, emotionally, unhelpful, sister, odysseus, preseason,
# Nearest to of: the, dodecahedra, in, inherited, by, nyasaland, a, chairmanship,
# Nearest to use: pedals, deprecated, imposes, kilocalories, gatt, electromotive, omit, ephemerides,
# Nearest to as: ides, often, mahathir, synthesisers, primitives, allophone, shalem, ours,
# Nearest to eight: nine, three, two, four, six, one, zero, seven,
# Nearest to running: route, belarussian, nok, fianna, freenet, kombinate, queue, voices,
# Nearest to arts: sciences, studied, college, specialized, televison, attending, wushu, humanities,
# Nearest to institute: doctorate, universities, undergraduate, uiuc, faculty, science, ph, jin,
# Nearest to operations: xnor, array, evacuation, stalingrad, rijndael, mortars, keep, carrier,
# Nearest to placed: coronal, built, disgrace, spores, freedom, electrolysis, wind, socialiste,
# Nearest to know: player, anybody, we, fill, someone, laments, thing, answers,
# Nearest to http: www, edu, com, pdf, html, gov, htm, https,
# Nearest to animals: jodie, social, orangutan, specimens, eaters, linnaeus, mauricio, sensations,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0047 0.3937 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9878 0.3839 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0065 0.3809 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0127 0.3787 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0987 0.3828 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0545 0.3376 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0053 0.3826 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9944 0.3841 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0166 0.3807 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9926 0.3805 sec/batch
# Nearest to d: zquez, sculptor, jacobson, alain, lakewood, ayres, milburn, maybach,
# Nearest to will: espouse, unskilled, any, everlasting, hackerdom, metaphorical, mentats, requires,
# Nearest to is: denotes, agha, shaanxi, there, infty, urartu, rangle, kets,
# Nearest to he: had, professor, his, sister, him, son, odysseus, unhelpful,
# Nearest to of: the, dodecahedra, in, inherited, a, by, from, ozark,
# Nearest to use: pedals, deprecated, imposes, omit, gatt, electromotive, uses, kilocalories,
# Nearest to as: often, ides, mahathir, synthesisers, allophone, ours, sardis, shalem,
# Nearest to eight: nine, three, two, four, six, one, zero, seven,
# Nearest to running: backwards, route, belarussian, nok, processor, queue, freenet, run,
# Nearest to arts: sciences, studied, college, aikido, aiki, wushu, humanities, attending,
# Nearest to institute: doctorate, universities, undergraduate, faculty, uiuc, ph, science, gingerbread,
# Nearest to operations: xnor, array, evacuation, rijndael, mortars, able, stalingrad, completion,
# Nearest to placed: built, disgrace, coronal, wind, spores, nave, freedom, phalaris,
# Nearest to know: anybody, we, player, laments, fill, answers, someone, thing,
# Nearest to http: www, com, edu, pdf, html, gov, htm, https,
# Nearest to animals: jodie, social, orangutan, eaters, linnaeus, specimens, adapts, denizens,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0059 0.3868 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9410 0.3821 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0240 0.3827 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0090 0.3828 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0234 0.3822 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0010 0.3824 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8989 0.3852 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9760 0.3854 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9513 0.3812 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9512 0.3822 sec/batch
# Nearest to d: jacobson, particle, zquez, maybach, alain, physica, reasonably, sculptor,
# Nearest to will: espouse, any, mentats, unskilled, everlasting, hackerdom, duly, requires,
# Nearest to is: kets, it, infty, there, shaanxi, denotes, required, triglyceride,
# Nearest to he: had, professor, his, preseason, him, odysseus, unhelpful, career,
# Nearest to of: the, in, dodecahedra, a, inherited, has, from, by,
# Nearest to use: pedals, imposes, deprecated, gatt, omit, electromotive, uses, enactment,
# Nearest to as: often, ides, mahathir, allophone, ours, synthesisers, result, shalem,
# Nearest to eight: three, nine, two, four, six, zero, one, seven,
# Nearest to running: route, backwards, belarussian, nok, kombinate, handlebar, voices, impatience,
# Nearest to arts: sciences, studied, college, aikido, humanities, aiki, wushu, televison,
# Nearest to institute: doctorate, universities, undergraduate, uiuc, faculty, gingerbread, jin, science,
# Nearest to operations: xnor, array, evacuation, rijndael, vaucher, keep, stalingrad, overheat,
# Nearest to placed: built, coronal, disgrace, wind, electrolysis, freedom, spores, phalaris,
# Nearest to know: player, anybody, we, fill, thing, answers, laments, someone,
# Nearest to http: www, edu, com, html, pdf, gov, htm, https,
# Nearest to animals: jodie, social, orangutan, eaters, linnaeus, specimens, adapts, herbivores,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0116 0.3891 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9986 0.3814 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9707 0.3789 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0104 0.3851 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0199 0.3811 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9673 0.3808 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9955 0.3831 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9867 0.3839 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9982 0.3886 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9835 0.3845 sec/batch
# Nearest to d: alain, jacobson, zquez, sculptor, maybach, particle, ayres, morrie,
# Nearest to will: espouse, any, everlasting, unskilled, mentats, metaphorical, duly, hackerdom,
# Nearest to is: denotes, infty, shaanxi, it, there, rangle, kets, required,
# Nearest to he: had, professor, his, him, preseason, career, unhelpful, emotionally,
# Nearest to of: the, in, a, dodecahedra, by, from, inherited, has,
# Nearest to use: pedals, kilocalories, gatt, imposes, omit, electromotive, deprecated, erythematosus,
# Nearest to as: often, ides, mahathir, synthesisers, in, relegated, ours, hearty,
# Nearest to eight: nine, four, three, two, six, one, seven, zero,
# Nearest to running: route, nok, belarussian, backwards, kombinate, fianna, freenet, voices,
# Nearest to arts: sciences, studied, college, aikido, aiki, humanities, wushu, televison,
# Nearest to institute: doctorate, universities, uiuc, undergraduate, dowd, gingerbread, jin, wellcome,
# Nearest to operations: xnor, evacuation, array, rijndael, stalingrad, overheat, vaucher, completion,
# Nearest to placed: built, disgrace, coronal, electrolysis, wind, sliding, spores, socialiste,
# Nearest to know: player, anybody, we, someone, answers, thing, fill, leu,
# Nearest to http: www, com, edu, html, pdf, htm, gov, https,
# Nearest to animals: jodie, orangutan, eaters, linnaeus, social, specimens, herbivores, preyed,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0245 0.3898 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9900 0.3854 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9638 0.3824 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9809 0.3812 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0079 0.3817 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9949 0.3814 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9524 0.3810 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9653 0.3869 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9934 0.3838 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0070 0.3842 sec/batch
# Nearest to d: zquez, jacobson, alain, particle, maybach, sculptor, torre, morrie,
# Nearest to will: espouse, any, unskilled, everlasting, mentats, cadaver, duly, metaphorical,
# Nearest to is: there, it, shaanxi, denotes, kets, infty, created, agha,
# Nearest to he: professor, had, him, his, preseason, unhelpful, sister, career,
# Nearest to of: the, a, in, by, inherited, from, dodecahedra, nyasaland,
# Nearest to use: pedals, gatt, kilocalories, imposes, omit, electromotive, deprecated, uses,
# Nearest to as: often, ides, mahathir, in, synthesisers, relegated, result, allophone,
# Nearest to eight: three, four, nine, two, six, one, zero, seven,
# Nearest to running: route, nok, freenet, fianna, backwards, belarussian, kombinate, queue,
# Nearest to arts: sciences, studied, college, aikido, aiki, humanities, wushu, televison,
# Nearest to institute: doctorate, universities, uiuc, wellcome, gingerbread, dowd, jin, undergraduate,
# Nearest to operations: evacuation, xnor, array, rijndael, stalingrad, vaucher, sangamon, keep,
# Nearest to placed: built, coronal, electrolysis, disgrace, wind, informational, socialiste, spores,
# Nearest to know: player, anybody, we, answers, someone, fill, something, thing,
# Nearest to http: www, com, edu, gov, html, htm, https, pdf,
# Nearest to animals: jodie, orangutan, eaters, specimens, linnaeus, preyed, social, adapts,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9571 0.3913 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0898 0.3851 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0387 0.3824 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0541 0.3824 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9619 0.3818 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9428 0.3782 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9806 0.3850 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9129 0.3825 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9789 0.3840 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9794 0.3840 sec/batch
# Nearest to d: sculptor, zquez, particle, alain, maybach, torre, morrie, theologian,
# Nearest to will: espouse, unskilled, everlasting, any, mentats, hackerdom, metaphorical, duly,
# Nearest to is: denotes, it, agha, shaanxi, infty, there, created, kets,
# Nearest to he: professor, had, his, him, unhelpful, career, exposition, emotionally,
# Nearest to of: the, in, a, by, dodecahedra, from, inherited, s,
# Nearest to use: pedals, kilocalories, electromotive, omit, uses, gatt, deprecated, imposes,
# Nearest to as: often, mahathir, ides, synthesisers, result, primitives, in, delocalized,
# Nearest to eight: nine, one, three, four, two, six, seven, zero,
# Nearest to running: route, nok, handlebar, freenet, fianna, belarussian, backwards, kombinate,
# Nearest to arts: studied, sciences, wushu, aikido, aiki, specialized, humanities, art,
# ...
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7463 0.3820 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8489 0.3790 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7958 0.3802 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8201 0.3814 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8519 0.3809 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8695 0.3784 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8236 0.3815 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8621 0.3787 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9557 0.3787 sec/batch
# Nearest to d: torre, particle, zquez, theologian, morrie, afrikaans, kernel, ayres,
# Nearest to will: allocation, duly, so, everlasting, supremum, any, mentats, cutoff,
# Nearest to is: of, a, it, and, there, also, in, has,
# Nearest to he: his, him, had, professor, unhelpful, was, son, sent,
# Nearest to of: the, a, in, by, and, is, to, with,
# Nearest to use: using, used, steinem, worthies, omit, bass, transmitting, as,
# Nearest to as: in, often, of, to, and, is, the, are,
# Nearest to eight: four, one, zero, three, nine, two, six, five,
# Nearest to running: nomination, route, ventura, freenet, midrange, cystitis, superseded, lines,
# Nearest to arts: aiki, sciences, aikido, wushu, art, studied, humanities, specialized,
# Nearest to institute: universities, doctorate, dowd, industrialist, institution, irvine, breslau, gingerbread,
# Nearest to operations: xnor, lcm, array, rijndael, atomic, evacuation, carrier, commencement,
# Nearest to placed: informational, coronal, sliding, built, electrolysis, nave, hello, illustration,
# Nearest to know: we, someone, anybody, something, fill, myself, heiland, answers,
# Nearest to http: www, htm, edu, gov, html, com, https, php,
# Nearest to animals: jodie, adapts, preyed, eaters, denizens, embargo, eusocial, unfair,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8359 0.3887 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8165 0.3801 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8305 0.3800 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8438 0.3802 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8524 0.3776 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8789 0.3790 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8532 0.3825 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8484 0.3798 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8801 0.3800 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8493 0.3833 sec/batch
# Nearest to d: torre, particle, morrie, kernel, zquez, theologian, meisner, afrikaans,
# Nearest to will: allocation, everlasting, duly, any, plenipotentiary, espouse, supremum, mentats,
# Nearest to is: of, a, it, and, has, there, the, also,
# Nearest to he: his, him, professor, had, was, unhelpful, studied, graduated,
# Nearest to of: the, a, by, in, to, and, is, with,
# Nearest to use: using, omit, worthies, steinem, transmitting, merriam, usage, used,
# Nearest to as: often, in, of, to, the, and, from, result,
# Nearest to eight: four, one, nine, zero, three, two, six, five,
# Nearest to running: nomination, route, freenet, midrange, superseded, cystitis, ventura, kombinate,
# Nearest to arts: aiki, wushu, aikido, sciences, art, studied, specialized, humanities,
# Nearest to institute: universities, doctorate, dowd, industrialist, breslau, gingerbread, caymanian, institution,
# Nearest to operations: xnor, lcm, array, atomic, evacuation, rijndael, commencement, westward,
# Nearest to placed: informational, coronal, sliding, electrolysis, built, nave, hello, illustration,
# Nearest to know: we, anybody, something, someone, answers, heiland, myself, fill,
# Nearest to http: www, htm, edu, gov, html, com, https, php,
# Nearest to animals: jodie, preyed, adapts, denizens, eaters, unfair, eusocial, embargo,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8415 0.3845 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8563 0.3786 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8406 0.3814 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8266 0.3812 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8915 0.3793 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8451 0.3843 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9698 0.3833 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8848 0.3805 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9175 0.3769 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7983 0.3808 sec/batch
# Nearest to d: theologian, torre, zquez, morrie, particle, afrikaans, kernel, sculptor,
# Nearest to will: allocation, everlasting, espouse, duly, supremum, plenipotentiary, cutoff, mentats,
# Nearest to is: of, a, it, there, and, are, also, has,
# Nearest to he: him, his, had, professor, was, studied, graduated, unhelpful,
# Nearest to of: the, a, in, by, and, to, s, with,
# Nearest to use: using, as, steinem, not, used, daunting, deb, worthies,
# Nearest to as: often, of, in, to, and, the, result, from,
# Nearest to eight: four, one, nine, zero, three, six, two, five,
# Nearest to running: nomination, route, midrange, superseded, freenet, cystitis, helier, ventura,
# Nearest to arts: aiki, wushu, aikido, sciences, taekwondo, art, humanities, jiu,
# Nearest to institute: universities, doctorate, dowd, breslau, gingerbread, industrialist, caymanian, rainbow,
# Nearest to operations: xnor, lcm, atomic, array, evacuation, completion, rijndael, commencement,
# Nearest to placed: informational, coronal, sliding, electrolysis, hello, built, nave, emigr,
# Nearest to know: we, anybody, something, someone, answers, myself, tell, fill,
# Nearest to http: www, htm, edu, gov, html, com, https, php,
# Nearest to animals: jodie, unfair, denizens, preyed, adapts, orangutan, eaters, embargo,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7982 0.3811 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.9076 0.3791 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7632 0.3820 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8722 0.3824 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8700 0.3873 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8510 0.3840 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9081 0.1827 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8145 0.3835 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8329 0.3815 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8267 0.3829 sec/batch
# Nearest to d: theologian, zquez, carleton, sculptor, particle, torre, morrie, meisner,
# Nearest to will: duly, everlasting, allocation, hackerdom, espouse, supremum, plenipotentiary, cutoff,
# Nearest to is: it, a, of, and, there, also, the, has,
# Nearest to he: his, him, was, had, professor, studied, at, son,
# Nearest to of: the, in, a, by, and, to, with, an,
# Nearest to use: worthies, usage, using, steinem, used, omit, daunting, brahmic,
# Nearest to as: often, in, of, and, result, the, from, to,
# Nearest to eight: one, four, nine, zero, three, six, seven, two,
# Nearest to running: nomination, midrange, route, freenet, lines, superseded, cystitis, ventura,
# Nearest to arts: aikido, aiki, wushu, taekwondo, sciences, jiu, art, humanities,
# Nearest to institute: universities, doctorate, dowd, breslau, industrialist, gingerbread, caymanian, institution,
# Nearest to operations: xnor, lcm, atomic, array, completion, vaucher, evacuation, hysterical,
# Nearest to placed: informational, coronal, sliding, electrolysis, nave, built, hello, emigr,
# Nearest to know: we, anybody, someone, something, answers, myself, fill, heiland,
# Nearest to http: www, htm, edu, gov, html, com, https, php,
# Nearest to animals: jodie, adapts, unfair, preyed, denizens, orangutan, eaters, eusocial,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8311 0.3954 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7944 0.3904 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8358 0.3834 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7673 0.3795 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8644 0.3862 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8358 0.3844 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8536 0.3820 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7523 0.3852 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7901 0.3842 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8172 0.3809 sec/batch
# Nearest to d: zquez, particle, morrie, kernel, theologian, torre, carleton, anthropoid,
# Nearest to will: allocation, everlasting, duly, so, any, mentats, cutoff, holy,
# Nearest to is: of, a, it, there, and, has, the, in,
# Nearest to he: him, his, had, professor, was, graduated, sent, studied,
# Nearest to of: the, in, a, by, and, is, to, an,
# Nearest to use: used, using, usage, worthies, daunting, steinem, as, bass,
# Nearest to as: in, often, of, the, and, to, is, result,
# Nearest to eight: four, one, zero, three, nine, two, six, seven,
# Nearest to running: nomination, lines, route, superseded, cystitis, ventura, freenet, midrange,
# Nearest to arts: aiki, aikido, wushu, sciences, taekwondo, jiu, art, profit,
# Nearest to institute: doctorate, universities, dowd, institution, industrialist, gingerbread, breslau, irvine,
# Nearest to operations: xnor, atomic, lcm, array, completion, hysterical, vaucher, overlap,
# Nearest to placed: informational, sliding, coronal, built, electrolysis, nave, hello, emigr,
# Nearest to know: we, anybody, someone, answers, something, fill, what, myself,
# Nearest to http: www, htm, edu, gov, html, com, https, php,
# Nearest to animals: jodie, adapts, unfair, orangutan, denizens, preyed, understandings, embargo,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7598 0.3852 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7887 0.3813 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8727 0.3830 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8195 0.3830 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8222 0.3821 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8893 0.3797 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8664 0.3814 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8046 0.3898 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8313 0.3882 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8215 0.3887 sec/batch
# Nearest to d: particle, zquez, torre, morrie, theologian, kernel, anthropoid, carleton,
# Nearest to will: everlasting, duly, allocation, so, cutoff, mentats, holy, plenipotentiary,
# Nearest to is: of, a, it, and, there, in, has, also,
# Nearest to he: his, him, had, professor, unhelpful, was, graduated, son,
# Nearest to of: the, in, a, by, and, is, as, s,
# Nearest to use: using, used, worthies, omit, as, daunting, bomba, cabalistic,
# Nearest to as: often, in, of, and, the, is, to, result,
# Nearest to eight: four, one, zero, three, nine, six, two, seven,
# Nearest to running: nomination, route, lines, superseded, midrange, ventura, freenet, cystitis,
# Nearest to arts: aiki, aikido, wushu, sciences, art, profit, beaux, jiu,
# Nearest to institute: universities, dowd, doctorate, industrialist, caymanian, irvine, institution, gingerbread,
# Nearest to operations: xnor, atomic, lcm, sangamon, evacuation, commencement, array, completion,
# Nearest to placed: sliding, informational, coronal, electrolysis, built, hello, nave, cardboard,
# Nearest to know: we, anybody, something, someone, fill, myself, answers, heiland,
# Nearest to http: www, htm, edu, gov, html, com, https, php,
# Nearest to animals: jodie, unfair, preyed, adapts, denizens, orangutan, eaters, understandings,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8599 0.3946 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8175 0.3868 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8173 0.3872 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8639 0.3877 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8934 0.3854 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8389 0.3840 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8375 0.3849 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8367 0.3823 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8181 0.3820 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7916 0.3805 sec/batch
# Nearest to d: torre, zquez, kernel, particle, morrie, anthropoid, catecholamines, behaviorist,
# Nearest to will: allocation, everlasting, so, cutoff, duly, any, mentats, plenipotentiary,
# Nearest to is: of, a, it, there, and, the, in, as,
# Nearest to he: him, his, professor, had, unhelpful, studied, son, was,
# Nearest to of: the, in, a, by, and, to, is, an,
# Nearest to use: using, used, usage, as, omit, not, for, uses,
# Nearest to as: often, in, of, the, and, is, also, from,
# Nearest to eight: four, one, three, zero, nine, two, six, five,
# Nearest to running: nomination, superseded, midrange, lines, freenet, route, cystitis, ventura,
# Nearest to arts: aiki, aikido, wushu, sciences, art, profit, beaux, jiu,
# Nearest to institute: universities, industrialist, dowd, doctorate, gingerbread, breslau, irvine, caymanian,
# Nearest to operations: xnor, atomic, sangamon, lcm, array, evacuation, completion, sudanese,
# Nearest to placed: informational, sliding, coronal, electrolysis, hello, nave, angkor, emigr,
# Nearest to know: we, anybody, something, someone, myself, fill, answers, think,
# Nearest to http: www, htm, edu, gov, html, com, https, php,
# Nearest to animals: jodie, unfair, denizens, adapts, preyed, orangutan, mauricio, understandings,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8573 0.3886 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8218 0.3809 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9101 0.3833 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9095 0.3812 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8720 0.3773 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8536 0.3799 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7731 0.3786 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8199 0.3784 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7332 0.3796 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8556 0.3842 sec/batch
# Nearest to d: theologian, zquez, morrie, torre, kernel, meisner, sculptor, carleton,
# Nearest to will: allocation, everlasting, so, if, supremum, cutoff, any, hackerdom,
# Nearest to is: a, of, it, there, also, and, in, the,
# Nearest to he: his, him, had, studied, was, professor, unhelpful, graduated,
# Nearest to of: the, in, a, by, and, is, s, with,
# Nearest to use: using, for, worthies, used, uses, as, omit, some,
# Nearest to as: often, in, of, the, and, from, also, a,
# Nearest to eight: one, four, zero, nine, three, two, six, five,
# Nearest to running: nomination, lines, superseded, route, helier, midrange, cystitis, ventura,
# Nearest to arts: aiki, aikido, wushu, art, jiu, sciences, taekwondo, profit,
# Nearest to institute: universities, industrialist, dowd, doctorate, breslau, irvine, gingerbread, qing,
# Nearest to operations: xnor, atomic, array, lcm, sangamon, completion, commencement, rijndael,
# Nearest to placed: informational, sliding, coronal, electrolysis, emigr, hello, nave, angkor,
# Nearest to know: we, anybody, someone, something, think, myself, fill, tell,
# Nearest to http: www, htm, edu, gov, com, html, https, php,
# Nearest to animals: jodie, unfair, denizens, adapts, preyed, orangutan, embargo, mauricio,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8404 0.3874 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8377 0.3857 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
